# %%
def greet_user():
    """Ask the user for their name and greet them"""
    name = input("Enter your name:")
    print(f"Hello, {name}! Welcome to the course.")

# %%
def calculate_total(price, quantity):
    total = price * quantity
    return total
    item_price = 19.99
    item_quantity = 3
    bill_total = calculate_total(item_price, item_quantity)
    print("Total bill:", bill_total)

# %%
def checkout(amount, shipping=5.0): # shipping has default value of 5.0
    final_amount = amount + shipping
    return final_amount
print("Order 1 total:", checkout(50)) # Uses default shipping of $5
print("Order 2 total:", checkout(50, shipping=10)) # Overrides with $10 shipping
# Out:
# Order 1 total: 55.0
# Order 2 total: 60

# %%
def register_student(name, program, year):
    print("------- Student Registration -------")
    print(f"Name : {name}")
    print(f"Program : {program}")
    print(f"Year : {year}")
    print("-----------------------------------")

# %%
def average_score(*scores):
    """Calculate average of any number of scores."""
    if not scores:
        print("No scores provided.")
        return None
    total = sum(scores)
    avg = total / len(scores)
    print(f"Scores: {scores}")
    print(f"Average: {avg}")
    return avg
average_score(80, 90, 75) # 3 arguments
average_score(100, 95) # 2 arguments
average_score() # 0 arguments
# Out:
# Scores: (80, 90, 75)
# Average: 81.66666666666667
# Scores: (100, 95)
# Average: 97.5
# No scores provided.

# %%
def create_profile(**info):
    """Create a user profile with any number of attributes."""
    if not info:
        print("Empty profile.")
        return
    print("------- User Profile -------")
    for key, value in info.items():
        print(f"{key.capitalize()}: {value}")
    print("----------------------------")
create_profile(name="K", role="Professor", department="CS")
create_profile(name="Sam", city="Sacramento")
create_profile()
# Out:
# ------- User Profile -------
# Name: K
# Role: Professor
# Department: CS
# ----------------------------
# ------- User Profile -------
# Name: Sam
# City: Sacramento
# ----------------------------
# Empty profile.

# %%
def log_event(event_type, *details, **metadata):
    """Log an event with details and metadata."""
    print("=== Event Log ===")
    print(f"Type: {event_type}")
    if details:
        print(f"Details: {details}")
    else:
        print("Details: (none)")
    if metadata:
        print("Metadata:")
        for key, value in metadata.items():
            print(f" {key} = {value}")
    else:
        print("Metadata: (none)")
    print("=================")
log_event("LOGIN", "Success", user="K", ip="192.168.0.10")
log_event("FILE_UPLOAD", "report.pdf", size="2MB")
log_event("PING")
# Out:
# === Event Log ===
# Type: LOGIN
# Details: ('Success',)
# Metadata:
#  user = K
#  ip = 192.168.0.10
# =================
# === Event Log ===
# Type: FILE_UPLOAD
# Details: ('report.pdf',)
# Metadata:
#  size = 2MB
# =================
# === Event Log ===
# Type: PING
# Details: (none)
# Metadata: (none)
# =================

# %%
def analyze_sales(sales):
    """Analyze sales data and return min, max, total, and average."""
    if not sales:
        return None, None, 0, 0
    min_sale = min(sales)
    max_sale = max(sales)
    total = sum(sales)
    average = total / len(sales)
    return min_sale, max_sale, total, average
week_sales = [120, 150, 90, 200, 175]
min_s, max_s, total_s, avg_s = analyze_sales(week_sales)
print(f"Min sale : ${min_s}")
print(f"Max sale : ${max_s}")
print(f"Total sale: ${total_s}")
print(f"Average : ${avg_s:.2f}")
# Out:
# Min sale : $90
# Max sale : $200
# Total sale: $735
# Average : $147.00

# %%
balance = 1000 # Global variable
def deposit_correct(amount):
    global balance # Declare that we're using the global balance
    balance = balance + amount
    print(f"Deposited ${amount}, new balance = ${balance}")
def deposit_wrong(amount):
    balance = balance + amount # ERROR! Can't reference before assignment
    return balance
print("Initial balance:", balance)
deposit_correct(200)
print("After deposit:", balance)
# Out:
# Initial balance: 1000
# Deposited $200, new balance = $1200
# After deposit: 1200

# %%
def ten_percent_discount(amount):
    return amount * 0.9
def flat_five_discount(amount):
    return amount - 5
def apply_discount(amount, discount_func):
    """Apply a discount function to an amount."""
    new_amount = discount_func(amount)
    print(f"Original: ${amount}, After discount: ${new_amount}")
    return new_amount
apply_discount(100, ten_percent_discount)
apply_discount(100, flat_five_discount)
# Out:
# Original: $100, After discount: $90.0
# Original: $100, After discount: $95
# 95

# %%
square = lambda x: x ** 2
print(square(5)) # Output: 25
# Lambda with sorted()
products = [
("Notebook", 4.99),
("Pen", 1.49),
("Backpack", 29.99),
("Bottle", 9.99),
]
sorted_by_price = sorted(products, key=lambda item: item[1])
print("Products sorted by price:")
for name, price in sorted_by_price:
    print(f" {name}: ${price}")
# Out:
# 25
# Products sorted by price:
#  Pen: $1.49
#  Notebook: $4.99
#  Bottle: $9.99
#  Backpack: $29.99

# %%
def celsius_to_fahrenheit(c):
    """
    Convert temperature from Celsius to Fahrenheit.
    Formula: F = (C * 9/5) + 32
    Args:
        c (float): Temperature in Celsius
    Returns:
        float: Temperature in Fahrenheit
    """
    return (c * 9 / 5) + 32
# Using the function
result = celsius_to_fahrenheit(37)
print(f"37°C in Fahrenheit = {result}°F")
# Accessing the docstring
print("\nDocstring:")
print(celsius_to_fahrenheit.__doc__)
# Out:
# 37°C in Fahrenheit = 98.6°F
#
# Docstring:
#
#     Convert temperature from Celsius to Fahrenheit.
#     Formula: F = (C * 9/5) + 32
#     Args:
#         c (float): Temperature in Celsius
#     Returns:
#         float: Temperature in Fahrenheit
