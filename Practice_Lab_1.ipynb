# %%
student_name="Alice"
age=20
height=1.65
is_enrolled=True
print(student_name)
print(age)
# Out:
# Alice
# 20

# %%
x=10
y=3
print(x+y)
a="10"
b="3"
print(a+b)
# Out:
# 13
# 103

# %%
value=42
print(type(value))
value="hello"
print(type(value))
# Out:
# <class 'int'>
# <class 'str'>

# %%
hours_worked=5
hourly_rate=10
total_pay=hours_worked*hourly_rate
print(total_pay)
# Out:
# 50

# %%
age=16
if age >=18:
  print("Adult")
else:
    print("Minor")
# Out:
# Minor

# %%
score=82
if score >=90:
  print("A")
elif score >=80:
  print("B")
elif score >=70:
  print("C")
else:
  print("F")
# Out:
# B

# %%
if 18<=age<=65:
  print("Adult")
# Out:
# Adult
